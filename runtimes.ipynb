# %%
import pandas as pd 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 8]

# %%
headers = ["recursion_limit", "run_time"]

df1 = pd.read_csv('quick_sort40000.csv', names=headers)
df2 = pd.read_csv('quick_sort80000.csv', names=headers)
df3 = pd.read_csv('quick_sort160000.csv', names=headers)
df4 = pd.read_csv('quick_sort320000.csv', names=headers)

df4.head(50)
# Out:
#     recursion_limit  run_time
# 0                 2  1.813597
# 1                 4  1.665549
# 2                 6  1.581074
# 3                 8  1.588650
# 4                10  1.620399
# 5                12  1.523260
# 6                14  1.655785
# 7                16  1.556163
# 8                18  1.627687
# 9                20  1.395177
# 10               22  1.564820
# 11               24  1.739200
# 12               26  1.527620
# 13               28  1.628354
# 14               30  1.577418
# 15               32  1.539880
# 16               34  1.640192
# 17               36  1.557170
# 18               38  1.576872
# 19               40  1.617931
# 20               42  1.588111
# 21               44  1.512489
# 22               46  1.662393
# 23               48  1.573697
# 24               50  1.589391
# 25               52  1.491562
# 26               54  1.589553
# 27               56  1.594055
# 28               58  1.652595
# 29               60  1.486694
# ...

# %%
min_val_loc_df1 = tuple(df1.loc[df1['run_time'].idxmin()])
min_val_loc_df2 = tuple(df2.loc[df2['run_time'].idxmin()])
min_val_loc_df3 = tuple(df3.loc[df3['run_time'].idxmin()])
min_val_loc_df4 = tuple(df4.loc[df4['run_time'].idxmin()])
print(min_val_loc_df1)
print(min_val_loc_df2)
print(min_val_loc_df3)
print(min_val_loc_df4)
# Out:
# (102.0, 0.12831422000000006)
# (290.0, 0.2628656119999988)
# (6.0, 0.6376901669999882)
# (274.0, 1.3940404429999944)

# %%
ax1 = df1.plot(title='Recursion Runs', x='recursion_limit', y='run_time', label='size=4000',colormap='Paired')
ax1.annotate(str(min_val_loc_df1),min_val_loc_df1,arrowprops=dict(facecolor='black', shrink=0.01))

df2.plot(ax=ax1,x='recursion_limit', y='run_time',label='size=8000')
ax1.annotate(str(min_val_loc_df2),min_val_loc_df2,arrowprops=dict(facecolor='black', shrink=0.01))

df3.plot(ax=ax1,x='recursion_limit', y='run_time',label='size=160000')
ax1.annotate(str(min_val_loc_df3),min_val_loc_df3,arrowprops=dict(facecolor='black', shrink=0.01))


df4.plot(ax=ax1,x='recursion_limit', y='run_time',label='size=320000')
ax1.annotate(str(min_val_loc_df4),min_val_loc_df4,arrowprops=dict(facecolor='black', shrink=0.01))
plt.xlabel('recursion_limits')
plt.ylabel('run_times')
# plt.show()
# Out:
# Text(0, 0.5, 'run_times')

# %%
headers = ["size", "run_time"]

df1_random = pd.read_csv("random_built_in_sorted_fn.csv", names=headers)
df2_random = pd.read_csv("random_quick_sort.csv", names=headers)
df3_random = pd.read_csv("random_quick_sort_m3.csv", names=headers)
df4_random= pd.read_csv("random_quickSortMyPivotTest.csv", names=headers)

min_val_loc_df1_random = tuple(df1_random.loc[df1_random['run_time'].idxmin()])
min_val_loc_df2_random = tuple(df2_random.loc[df2_random['run_time'].idxmin()])
min_val_loc_df3_random = tuple(df3_random.loc[df3_random['run_time'].idxmin()])
min_val_loc_df4_random = tuple(df4_random.loc[df4_random['run_time'].idxmin()])
print(min_val_loc_df1_random)
print(min_val_loc_df2_random)
print(min_val_loc_df3_random)
print(min_val_loc_df4_random)

df1_random.head(15)
# Out:
# (10.0, 6.176999988838362e-06)
# (10.0, 1.6723999976875348e-05)
# (10.0, 2.721699999597149e-05)
# (10.0, 1.1699000026510475e-05)
#      size  run_time
# 0      10  0.000006
# 1     100  0.000017
# 2     500  0.000123
# 3    1000  0.000332
# 4    3000  0.000817
# 5    5000  0.001412
# 6    7000  0.002018
# 7    9000  0.001529
# 8   11000  0.001983
# 9   13000  0.002105
# 10  15000  0.002778
# 11  17000  0.003029
# 12  19000  0.003696
# 13  21000  0.004144
# 14  23000  0.004331

# %%
ax1 = df1_random.plot(title='Runtime Performance', x='size', y='run_time', label='random_built_in_sorted',colormap='Paired')

ax1.annotate(str(min_val_loc_df1_random),min_val_loc_df1_random,arrowprops=dict(facecolor='black', shrink=0.01))

df2_random.plot(ax=ax1,x='size', y='run_time',label='random_quick_sort')
ax1.annotate(str(min_val_loc_df2_random),min_val_loc_df2_random,arrowprops=dict(facecolor='black', shrink=0.01))

df3_random.plot(ax=ax1,x='size', y='run_time',label='random_quick_sort_m3')
ax1.annotate(str(min_val_loc_df3_random),min_val_loc_df3_random,arrowprops=dict(facecolor='black', shrink=0.01))


df4_random.plot(ax=ax1,x='size', y='run_time',label='random_quickSortMyPivotTest')
ax1.annotate(str(min_val_loc_df4_random),min_val_loc_df4_random,arrowprops=dict(facecolor='black', shrink=0.01))
plt.xlabel('size')
plt.ylabel('run_times')
# plt.show()
# Out:
# Text(0, 0.5, 'run_times')

# %%
headers = ["size", "run_time"]

df1_sorted = pd.read_csv("sorted_built_in_sorted_fn.csv", names=headers)
df2_sorted = pd.read_csv("sorted_quick_sort.csv", names=headers)
df3_sorted = pd.read_csv("sorted_quick_sort_m3.csv", names=headers)
df4_sorted = pd.read_csv("sorted_quickSortMyPivotTest.csv", names=headers)

min_val_loc_df1_sorted = tuple(df1_sorted.loc[df1_sorted['run_time'].idxmin()])
min_val_loc_df2_sorted = tuple(df2_sorted.loc[df2_sorted['run_time'].idxmin()])
min_val_loc_df3_sorted = tuple(df3_sorted.loc[df3_random['run_time'].idxmin()])
min_val_loc_df4_sorted = tuple(df4_sorted.loc[df4_sorted['run_time'].idxmin()])
print(min_val_loc_df1_sorted)
print(min_val_loc_df2_sorted)
print(min_val_loc_df3_sorted)
print(min_val_loc_df4_sorted)
# Out:
# (100.0, 5.633999990095618e-06)
# (10.0, 1.625200002308702e-05)
# (10.0, 1.0321999980078543e-05)
# (10.0, 4.754000030970929e-06)

# %%
ax1 = df1_sorted.plot(title='Runtime Performance', x='size', y='run_time', label='random_built_in_sorted',colormap='Paired')

# ax1.annotate(str(min_val_loc_df1_sorted),min_val_loc_df1_sorted,arrowprops=dict(facecolor='black', shrink=0.01))

df2_sorted.plot(ax=ax1,x='size', y='run_time',label='sorted_quick_sort')
# ax1.annotate(str(min_val_loc_df2_sorted),min_val_loc_df2_sorted,arrowprops=dict(facecolor='black', shrink=0.01))

df3_sorted.plot(ax=ax1,x='size', y='run_time',label='sorted_quick_sort_m3')
# ax1.annotate(str(min_val_loc_df3_random),min_val_loc_df3_sorted,arrowprops=dict(facecolor='black', shrink=0.01))


df4_sorted.plot(ax=ax1,x='size', y='run_time',label='sorted_quickSortMyPivotTest')
# ax1.annotate(str(min_val_loc_df4_sorted),min_val_loc_df4_sorted,arrowprops=dict(facecolor='black', shrink=0.01))
plt.xlabel('size')
plt.ylabel('run_times')
# Out:
# Text(0, 0.5, 'run_times')
